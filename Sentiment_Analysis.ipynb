# %%
import nltk
import pandas as pd
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/dishant/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
df = pd.read_csv("bitcoin_tweets.csv")
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text  Emojis Comments Likes  \
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...     NaN       76   487
# 1  I've bought as much #bitcoin as I can possibly...     NaN      153    37
# 2  The vast majority of people are crypto-aware. ...     NaN       97   113
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...     NaN      170  1.7K
# 4  Time to spartan up. They are coming for your #...     NaN       75    39
#
#   Retweets
# 0     1.9K
# 1      718
# 2       1K
# 3     1.4K
# 4      524

# %%
df = df.drop(columns = ["Emojis"])
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text Comments Likes Retweets
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...       76   487     1.9K
# 1  I've bought as much #bitcoin as I can possibly...      153    37      718
# 2  The vast majority of people are crypto-aware. ...       97   113       1K
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...      170  1.7K     1.4K
# 4  Time to spartan up. They are coming for your #...       75    39      524

# %%
df.dropna(inplace=True)
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text Comments Likes Retweets
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...       76   487     1.9K
# 1  I've bought as much #bitcoin as I can possibly...      153    37      718
# 2  The vast majority of people are crypto-aware. ...       97   113       1K
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...      170  1.7K     1.4K
# 4  Time to spartan up. They are coming for your #...       75    39      524

# %%
df['scores'] = df['Text'].apply(lambda review: sid.polarity_scores(review))
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text Comments Likes Retweets  \
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...       76   487     1.9K
# 1  I've bought as much #bitcoin as I can possibly...      153    37      718
# 2  The vast majority of people are crypto-aware. ...       97   113       1K
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...      170  1.7K     1.4K
# 4  Time to spartan up. They are coming for your #...       75    39      524
#
#                                               scores
# 0  {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.076, 'neu': 0.924, 'pos': 0.0, 'comp...
# 3  {'neg': 0.037, 'neu': 0.707, 'pos': 0.255, 'co...
# 4  {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compou...

# %%
df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])
df = df.drop(columns = ["scores"])
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text Comments Likes Retweets  \
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...       76   487     1.9K
# 1  I've bought as much #bitcoin as I can possibly...      153    37      718
# 2  The vast majority of people are crypto-aware. ...       97   113       1K
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...      170  1.7K     1.4K
# 4  Time to spartan up. They are coming for your #...       75    39      524
#
#    compound
# 0    0.4404
# 1    0.0000
# 2   -0.4215
# 3    0.9402
# 4    0.5719

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
df.head()
# Out:
#                             UserName           Handle  \
# 0                        Erin Malone     @ErinEMalone
# 1                   Linkamus ₿ ∞/21M    @VersusTheMan
# 2                      Ben Armstrong   @Bitboy_Crypto
# 3                        AirdropStar   @AirdropStario
# 4  Jason A. Williams “Parabolic Guy”  @GoingParabolic
#
#                   Timestamp  \
# 0  2021-07-18T23:23:20.000Z
# 1  2021-07-18T23:02:42.000Z
# 2  2021-07-18T21:50:17.000Z
# 3  2021-07-18T20:52:26.000Z
# 4  2021-07-18T20:50:31.000Z
#
#                                                 Text Comments Likes Retweets  \
# 0  1. 10 weeks ago, I joined the \n@lightning\n n...       76   487     1.9K
# 1  I've bought as much #bitcoin as I can possibly...      153    37      718
# 2  The vast majority of people are crypto-aware. ...       97   113       1K
# 3  YUKISwap Airdrop \n\n Task:           Up to 40...      170  1.7K     1.4K
# 4  Time to spartan up. They are coming for your #...       75    39      524
#
#    compound comp_score
# 0    0.4404        pos
# 1    0.0000        pos
# 2   -0.4215        neg
# 3    0.9402        pos
# 4    0.5719        pos

# %%
pos_count = 0
pos_score = 0.0
neg_count = 0
neg_score = 0.0
for index, row in df.iterrows():
    if row['comp_score'] == "pos":
        pos_count = pos_count + 1
        pos_score = pos_score + (row['compound']*float(row['Comments'][:-1]))
    elif row['comp_score'] == "neg":
        neg_count = neg_count + 1
        neg_score = neg_score + ((-1*row['compound'])*float(row['Comments'][:-1]))

# %%
pos_count
# Out:
# 103

# %%
neg_count
# Out:
# 24

# %%
pos_score
# Out:
# 528.3218499999999

# %%
neg_score
# Out:
# 130.5266

# %%
percnt = 0.0
if pos_score > neg_score:
    percnt = pos_score/(pos_score+neg_score) * 100
elif neg_score > pos_score:
    percnt = neg_score/(pos_score + neg_score)*100

# %%
percnt
# Out:
# 80.18867616672696
