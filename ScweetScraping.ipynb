# %% [markdown]
# # Scweet
# This is implementation of unofficial Twitter Scraping Library developed by Altimis which allows unlimited requests.

# %%
# !pip install Scweet==1.0

# %%
from Scweet.scweet import scrap
from Scweet.user import get_user_information, get_users_following, get_users_followers


# scrape top tweets with the words 'BTC' or 'Bitcoin' between dates 1st July to 4th July
data = scrap(words=['BTC','Bitcoin'], start_date="2021-07-01", max_date="2021-07-04", from_account = None, interval=1, 
    headless=True, display_type="Top", save_images=False, 
    resume=False, filter_replies=True, proximity=True)
# Out:
# Scraping on headless mode.
# looking for tweets between 2021-07-01 and 2021-07-02 ...
#  path : https://twitter.com/search?q=(BTC%20OR%20Bitcoin)%20until%3A2021-07-02%20since%3A2021-07-01%20%20-filter%3Areplies&src=typed_query&lf=on
# Tweet made at: 2021-07-01T06:17:13.000Z is found.
# Tweet made at: 2021-07-01T02:55:37.000Z is found.
# Tweet made at: 2021-07-01T06:55:40.000Z is found.
# Tweet made at: 2021-07-01T04:26:50.000Z is found.
# scroll  1
# Tweet made at: 2021-07-01T04:26:50.000Z is found.
# scroll  2
# scroll  3
# looking for tweets between 2021-07-02 and 2021-07-03 ...
#  path : https://twitter.com/search?q=(BTC%20OR%20Bitcoin)%20until%3A2021-07-03%20since%3A2021-07-02%20%20-filter%3Areplies&src=typed_query&lf=on
# Tweet made at: 2021-07-02T04:15:11.000Z is found.
# Tweet made at: 2021-07-02T13:25:15.000Z is found.
# Tweet made at: 2021-07-02T06:50:44.000Z is found.
# Tweet made at: 2021-07-02T04:14:35.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# ...

# %%
data.head()
# Out:
#                  UserScreenName       UserName                 Timestamp  \
# 0                 Maaz Anarwala      @maazanar  2021-07-01T06:17:13.000Z
# 1                      Brijesh!     @iBrijeshV  2021-07-01T02:55:37.000Z
# 2  BIGBULL CLUB PRIVATE LIMITED   @BigbullClub  2021-07-01T06:55:40.000Z
# 3                    Ajay Darji  @iamajaydarji  2021-07-01T04:26:50.000Z
# 4                    Ajay Darji  @iamajaydarji  2021-07-01T04:26:50.000Z
#
#                                                 Text  \
# 0  I just joined the \n@coinmarketcap\n @CROSS_WA...
# 1  I have put more money into $BTC through \n@Coi...
# 2  Learn Advanced Technical Analysis and Trading ...
# 3                                #bitcoin #USbitcoin
# 4                                #bitcoin #USbitcoin
#
#                                        Embedded_text Emojis Comments Likes  \
# 0  #CROSSWALLET X COINMARKETCAP $20.5K AIRDROP\n#...
# 1                                                         😁
# 2
# ...
